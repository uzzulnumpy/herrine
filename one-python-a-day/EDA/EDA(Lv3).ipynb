# %% [markdown]
# ### EDA 기초

# %%
import numpy as np
import pandas as pd
import seaborn as sns
# as 는 별칭 / 통상 이런 표현을 씀

# %%
import sklearn
model = sklearn.ensemble.RandomForestClassifier()

from sklearn import ensemble
model = ensemble.RandomForestClassifier()

from sklearn.ensemble import RandomClassifier()
model = RandomClassifier()

# %% [markdown]
# ---

# %% [markdown]
# #### pd.read_csv()

# %% [markdown]
# |파라미터|내용|
# |:----:|---|
# |FilePath|읽을 파일 Path, URL도 가능|
# |sep|구분자 입력, Default는 쉼표(',')|
# |header|파일의 데이터에 header가 없을 경우 none입력, Default는 header 읽음|
# |names|파일의 데이터에 header가 없을 경우에 명시적으로 컬럼명 입력 가능|
# |skiprows|앱력한 개수만큼 파일에서 행을 건너뛰고 읽음|
# |index_col|명시한 특정 컬럼을 index로 사용|
# |nrows|파일 최상위에서부터 입력한 개수만큼의 데이터만 읽음|
# |encoding|파일의 문자 인코딩 타입 입력, ex) cp949, utf-8|
# |comment|특정 문자는 주석으로 간주하고 읽지 않음|
# |chunksize|TextFileReader가 입력받을 데이터 개수 Return하여 특정 개수만큼 순서대로 읽음|

# %% [markdown]
# #### pd.read_excel(.xlsx)

# %% [markdown]
# |파라미터|내용|
# |---|----|
# |Path|excel 파일 경로|
# |sheet_name|읽을 Sheet name 명시|
#
# <br><br>
# **sheet_name** 특징<br><br>
# - 명시한 Sheet name만 읽음<br>
# - Default는 첫 번째 sheet<br>
# - None을 입력하면 모든 Sheet를 key = Sheetname, value = Data로 가져옴

# %%
import pandas as pd
from sklearn.datasets import load_iris

iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df['class'] = iris.target

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   class              150 non-null    int32
# dtypes: float64(4), int32(1)
# memory usage: 5.4 KB

# %%
df.shape
# Out:
# (150, 5)

# %%
df.tail()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      class
# 145      2
# 146      2
# 147      2
# 148      2
# 149      2

# %% [markdown]
# ### 결측치 유무 확인하기

# %%
df.isnull()[:5]
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0              False             False              False             False
# 1              False             False              False             False
# 2              False             False              False             False
# 3              False             False              False             False
# 4              False             False              False             False
#
#    class
# 0  False
# 1  False
# 2  False
# 3  False
# 4  False

# %%
df.isnull().sum()
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# class                0
# dtype: int64

# %% [markdown]
# ### 수치데이터 특성보기

# %%
df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)       class
# count        150.000000  150.000000
# mean           1.199333    1.000000
# std            0.762238    0.819232
# min            0.100000    0.000000
# 25%            0.300000    0.000000
# 50%            1.300000    1.000000
# 75%            1.800000    2.000000
# max            2.500000    2.000000

# %% [markdown]
# ### 변수분포 시각화

# %% [markdown]
# [seaborn 알아보기](https://github.com/rrkcl7733/playground/blob/main/Python_Study/_Seaborn_%ED%95%9C%EB%B2%88%EC%97%90_%EC%A0%9C%EB%8C%80%EB%A1%9C_%EB%B0%B0%EC%9A%B0%EA%B8%B0.ipynb)

# %%
import seaborn as sns

# %%
sns.pairplot(df, hue='class');

# %%
sns.scatterplot(data=df, x='sepal width (cm)', y='petal length (cm)', hue='class');

# %%
sns.histplot(data=df, x='sepal width (cm)', y='petal length (cm)', hue='class');
